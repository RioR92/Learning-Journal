# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# #CARA IMPORT / LOADING DATA ke Collab

# %%
pd.read_csv('/content/contoh.csv')
# Out:
#   kol1;kol2;kol3
# 0          1;3;3
# 1          6;2;8
# 2          2;8;9

# %%
# Masih belum rapih, perlu di separate

# %%
pd.read_csv('/content/contoh.csv',delimiter=';')
#syntax agar rapi pakai delimiter
# Out:
#    kol1  kol2  kol3
# 0     1     3     3
# 1     6     2     8
# 2     2     8     9

# %%
pd.read_csv('/content/Student_Marks.csv')
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
sdf = pd.read_csv('/content/Student_Marks.csv')
sdf
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('/content/nbaallelo.csv')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nbadf =pd.read_csv('/content/nbaallelo.csv')

nbadf
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %% [markdown]
# #Data Overview

# %%
nbadf.shape
#NBA Data Frame mempunyai 126,314 baris dan 23 kolom (126314,23)
# Out:
# (126314, 23)

# %%
nbadf.head()
#menunjukan 5 data teratas secara default.
#bisa di edit jadi berapa kolom sesuai yang diinginkan dengan cara input di sebelah head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
nbadf.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
#Untuk menunjukan seluruh kolom 
pd.set_option('display.max.column',None)

nbadf
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nbadf.head(11)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
#
# ...

# %%
#Untuk melihat data terakhir
#df.tail()

df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126304          98            1     CLE  Cavaliers   95  1708.1705  1716.8708
# ...

# %%
#menampilkan data secara acak
#df.sample -> defaultnya hanya menunjukan 1 data random

df.sample()
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 84316      42159  199903190PHI   NBA        0     1999  3/19/1999          23
#
#        is_playoffs team_id fran_id  pts      elo_i      elo_n  win_equiv  \
# 84316            0     PHI  Sixers  105  1542.2439  1555.8551   47.11359
#
#       opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 84316    LAL   Lakers       90  1645.2205  1631.6093             H
#
#       game_result  forecast notes
# 84316           W  0.495716   NaN

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 88384       44193  200012130POR   NBA        1     2001  12/13/2000
# 100029      50015  200504010MIL   NBA        1     2005    4/1/2005
# 111871      55936  200912230ORL   NBA        0     2010  12/23/2009
# 112476      56239  201002030NOH   NBA        0     2010    2/3/2010
# 45861       22931  198111190SDC   NBA        0     1982  11/19/1981
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 88384           24            0     LAL     Lakers   86  1610.5447  1604.3940
# 100029          71            0     MEM  Grizzlies   93  1556.8148  1566.1208
# 111871          29            0     ORL      Magic  102  1649.4722  1656.9830
# 112476          49            0     NOH   Pelicans   99  1502.6559  1494.8999
# 45861            9            0     SDC   Clippers  100  1445.5419  1436.5867
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# Melihat apakah ada missing value atau tidak.
# cara melihatnya adalah lihat per baris apakah angkanya sama dengan total entry data.
# ATAU bisa di lihat dari baris notes
# pada notes tertulis 5424 yg berarti terdapat data yang NON missing value sebanyak 5,424
# Sehingga total data missing value sekitar 121rb
# Di check setiap kolom apakah data typenya sudah sesuai -> contoh pada data di atas kolom date game typenya object,
# Sebaikanya kolom date game di rubah menjadi time

# %%
# Langkah ini di ambil untuk  menyortir data - dat yang tidak diperlukan

# %%
# CARA LAIN
# df.describe().T
# informasi statistika untuk data - data numerik saja.
# untuk data NON Numerik tidak masuk.

df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %%
# Dari informasi df.describe ini kita bisa lihat beberapa anomali
# CONTOH :
# year range dari 1947 - 2015 : Terlalu jauh/lama
# terdapat point 0 pada suatu game -> diragukan kebenarannya

# %% [markdown]
# ## Data Exploration

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
#SLICING data
df['team_id']
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
df[['team_id','fran_id']]
# Out:
#        team_id    fran_id
# 0          TRH    Huskies
# 1          NYK     Knicks
# 2          CHS      Stags
# 3          NYK     Knicks
# 4          DTF    Falcons
# ...        ...        ...
# 126309     CLE  Cavaliers
# 126310     GSW   Warriors
# 126311     CLE  Cavaliers
# 126312     CLE  Cavaliers
# 126313     GSW   Warriors
#
# [126314 rows x 2 columns]

# %%
df[['team_id','fran_id']].head(10)
# Out:
#   team_id       fran_id
# 0     TRH       Huskies
# 1     NYK        Knicks
# 2     CHS         Stags
# 3     NYK        Knicks
# 4     DTF       Falcons
# 5     WSC      Capitols
# 6     BOS       Celtics
# 7     PRO  Steamrollers
# 8     PIT       Ironmen
# 9     STB       Bombers

# %%
df['team_id'].unique()
#Melihat element di team_id
# Out:
# array(['TRH', 'NYK', 'CHS', 'DTF', 'WSC', 'BOS', 'PRO', 'PIT', 'STB',
#        'CLR', 'PHW', 'BLB', 'INJ', 'FTW', 'MNL', 'ROC', 'TRI', 'DNN',
#        'INO', 'SHE', 'WAT', 'AND', 'SYR', 'MLH', 'STL', 'DET', 'CIN',
#        'LAL', 'CHP', 'CHZ', 'SFW', 'BAL', 'PHI', 'CHI', 'SEA', 'OAK',
#        'ANA', 'SDR', 'KEN', 'INA', 'DNR', 'DLC', 'HSM', 'NOB', 'MNM',
#        'NJA', 'PTP', 'ATL', 'MIL', 'PHO', 'NYA', 'MMF', 'MNP', 'LAS',
#        'CAR', 'WSA', 'BUF', 'CLE', 'UTS', 'FLO', 'PTC', 'POR', 'VIR',
#        'TEX', 'MMP', 'HOU', 'GSW', 'KCO', 'MMT', 'SDA', 'CAP', 'SAA',
#        'NOJ', 'DNA', 'SSL', 'MMS', 'WSB', 'KCK', 'SDS', 'IND', 'NYN',
#        'DEN', 'SAS', 'NJN', 'SDC', 'UTA', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'VAN', 'TOR', 'WAS', 'MEM', 'NOH', 'CHA',
#        'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
df['team_id'].value_counts()
# Memunculkan jumlah kemunculan elements pada team id
# Menampilkan data dari tertinggi sampe terendah
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df['team_id'].value_counts().head(5)
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df['fran_id'].value_counts().head(5)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %%
# Pada 2 data di atas terdapat kejanggalan karena angka terbanyak dan teamnya berbeda.
# Seharusnya team dan angka kemunculan pada 2 data tersebut sama karena 1 team mempunyai 1 franchise name yg sama.

# %%
df.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# ### SLICING data pada data frame

# %%
df.loc[df['fran_id']=='Lakers', :].head()

# CARA BACANYA ADALAH
# df loc = Mencari berdasarkan label
# [df['fran_id'] = label yang berada di kolom fran_id
# =='lakers' = Yang namanya sama dengan lakers
# : = seluruhnya di tampilkan
# .head() = 5 data teratas
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
#
#       is_playoffs team_id fran_id  pts      elo_i      elo_n  win_equiv  \
# 1136            0     MNL  Lakers   84  1527.0000  1542.2545  51.218754
# 1152            0     MNL  Lakers   62  1542.2545  1536.2078  50.621624
# 1159            0     MNL  Lakers   55  1536.2078  1513.4880  48.341133
# 1170            0     MNL  Lakers   77  1513.4880  1524.9596  49.499451
# 1183            0     MNL  Lakers   90  1524.9596  1533.2726  50.330185
#
# ...

# %%
#Slicing lagi untuk  melihat beberapa kolom saja yg mau dilihat
df.loc[df['fran_id']=='Lakers',['year_id','team_id','fran_id']].head(11)
# Out:
#       year_id team_id fran_id
# 1136     1949     MNL  Lakers
# 1152     1949     MNL  Lakers
# 1159     1949     MNL  Lakers
# 1170     1949     MNL  Lakers
# 1183     1949     MNL  Lakers
# 1193     1949     MNL  Lakers
# 1202     1949     MNL  Lakers
# 1217     1949     MNL  Lakers
# 1229     1949     MNL  Lakers
# 1234     1949     MNL  Lakers
# 1241     1949     MNL  Lakers

# %%
#Kembali ke objective kenapa kok jumlah game terbanyak berbeda antara team_ida dan fran_id

# %%
df.loc[df['fran_id']=='Lakers','team_id'].value_counts()
# Function ini memiliki arti
# Pada bagian fran_id, system mencari yang namanya 'Lakers'
# Lalu kita tambahkan kolom team_id yang sama - sama menunjukan 'Lakers.
# value_counts digunakan karena untuk melihat total nama Lakers pada kolom tersebut.
# Terlihat hasilnya bahwa Lakers mempunyai 2 team_id yaitu LAL dan MNL
# Sehingga data tidak terlalu valid
# Jika kedua data LAL dan MNL di tambah maka totalnya adalah 6024 dan sesuai pada data fran_id
# Kesimpulan, LAKERS mempunyai 2 nama yang di akibatkan adanya perubahan nama pada tahun tertentu
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
 df.loc[df['fran_id']=='Lakers','pts'].mean()
# Out:
# 105.81739707835325

# %%
 df.loc[df['fran_id']=='Lakers','pts'].sum()
# Out:
# 637444

# %%
 df.loc[df['fran_id']=='Lakers','pts'].min()
# Out:
# 18

# %%
 df.loc[df['fran_id']=='Lakers','pts'].max()
# Out:
# 162

# %% [markdown]
# #QUERY

# %%
# Tujuannya untuk mengakses specific data dari data frame

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %% [markdown]
# #FILTERING DATA FRAME DARI QUERY(KONDISI).
# #BISA PAKAI & atau /

# %%
#FLITERING data
# dari tahun 2000 - 2010
# club Wizards
# points > 80
df[(df['year_id'] >2000) & 
   (df['year_id']<2010)&
   (df['fran_id']== 'Wizards')&
   (df['pts']>80)
    ]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 87764       43883  200010310ORL   NBA        1     2001  10/31/2000
# 87778       43890  200011010CHH   NBA        1     2001   11/1/2000
# 87841       43921  200011040TOR   NBA        1     2001   11/4/2000
# 87859       43930  200011070CHI   NBA        1     2001   11/7/2000
# 87890       43946  200011080WAS   NBA        0     2001   11/8/2000
# ...           ...           ...   ...      ...      ...         ...
# 110682      55342  200904040WAS   NBA        0     2009    4/4/2009
# 110727      55364  200904080CLE   NBA        1     2009    4/8/2009
# 110776      55389  200904100TOR   NBA        1     2009   4/10/2009
# 110827      55414  200904130WAS   NBA        0     2009   4/13/2009
# 110834      55418  200904150BOS   NBA        1     2009   4/15/2009
#
#         seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# ...

# %%
 df[(df['year_id'] >2000) & 
    (df['year_id']<2010)&
   (df['fran_id']== 'Wizards')&
   (df['pts']>80)
    ][['year_id','fran_id','pts','game_location']]
  
  # [[]] -> digunakan untuk filtering kolom mana saja yang ingin dilihat
# Out:
#         year_id  fran_id  pts game_location
# 87764      2001  Wizards   86             A
# 87778      2001  Wizards   95             A
# 87841      2001  Wizards   96             A
# 87859      2001  Wizards   88             A
# 87890      2001  Wizards   86             H
# ...         ...      ...  ...           ...
# 110682     2009  Wizards  104             H
# 110727     2009  Wizards   86             A
# 110776     2009  Wizards  100             A
# 110827     2009  Wizards   96             H
# 110834     2009  Wizards  107             A
#
# [690 rows x 4 columns]

# %%
#CONTOH LAIN
# 1. year_id [2005 -2012]
# 2. seasongame ganjil
# 3. pts > 90
# 4. game result W

# cari .shape

# %%
df[(df['year_id']>=2005) &
   (df['year_id']<=2012) &
   (df['seasongame'] % 2 != 0 )&
   (df['pts']>90) &
   (df['game_result'] == 'W')].shape
# Out:
# (4698, 23)

# %%
df[(df['year_id']>=2005) &
   (df['year_id']<=2012) &
   (df['seasongame'] % 2 != 0 )&
   (df['pts']>90) &
   (df['game_result'] == 'W')][['year_id','seasongame','pts','game_result']]
  
  #biar melihat beberap kolom saja
# Out:
#         year_id  seasongame  pts game_result
# 97887      2005           1  107           W
# 97893      2005           1   98           W
# 97895      2005           1  109           W
# 97898      2005           1  114           W
# 97901      2005           1  103           W
# ...         ...         ...  ...         ...
# 118405     2012          83   93           W
# 118411     2012          81  107           W
# 118412     2012          83   98           W
# 118421     2012          87   91           W
# 118424     2012          89  121           W
#
# [4698 rows x 4 columns]

# %%
# CARA LAIN

df.query("year_id >= 2005 & \
        year_id <= 2012 & \
        seasongame % 2 != 0 & \
        pts > 90 & \
        game_result == 'W'").shape
# Out:
# (4698, 23)

# %% [markdown]
# #QUERY Pakai LOC
#
# #### Sedikit kurang rapi dan dianjurkan pakai QUERY method saja

# %%
df.loc[(df['fran_id']=='Lakers') & (df['year_id']==2010), :]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 111037      55519  200910270LAL   NBA        0     2010  10/27/2009
# 111078      55540  200910300LAL   NBA        0     2010  10/30/2009
# 111113      55557  200911010LAL   NBA        0     2010   11/1/2009
# 111144      55573  200911030OKC   NBA        1     2010   11/3/2009
# 111153      55577  200911040HOU   NBA        1     2010   11/4/2009
# ...           ...           ...   ...      ...      ...         ...
# 113647      56824  201006080BOS   NBA        1     2010    6/8/2010
# 113649      56825  201006100BOS   NBA        1     2010   6/10/2010
# 113650      56826  201006130BOS   NBA        1     2010   6/13/2010
# 113653      56827  201006150LAL   NBA        0     2010   6/15/2010
# 113654      56828  201006170LAL   NBA        0     2010   6/17/2010
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %% [markdown]
# ## Grouping dan Aggregating

# %%
df.groupby(by='fran_id')[['pts']].mean()
#CARA BACANYA :
# Membuat group based on fran_id dan dilihat mean dari point seluruh data
# Secara default sesuai alphabetical order
# Out:
#                      pts
# fran_id
# Baltimore      79.698073
# Bombers        71.457831
# Bucks         103.700050
# Bulls         101.525192
# Capitols       76.931271
# Cavaliers      99.846719
# Celtics       104.466233
# Clippers      101.934905
# Colonels      111.625296
# Condors       115.446512
# Denver         77.709677
# Falcons        63.283333
# Floridians    112.654545
# Grizzlies      95.161738
# Hawks         101.805635
# Heat           96.627162
# Hornets        94.506711
# Huskies        66.583333
# Ironmen        61.233333
# Jazz          102.153305
# Jets           74.700000
# Kings         103.971689
# Knicks        100.970185
# Lakers        105.817397
# Magic          99.427277
# Mavericks     102.634915
# Nets          101.755723
# Nuggets       108.199029
# Olympians      81.078014
# Pacers        103.687722
# Packers        86.013889
# Pelicans       97.956522
# Pistons       101.373097
# Raptors        96.921665
# Rebels         71.015873
# ...

# %%
df.groupby(by='fran_id')[['pts']].mean().sort_values(by='pts', ascending=False).head()

#Ascending = False karena kita mau tampilakn dari tinggi ke rendah
# Out:
#                    pts
# fran_id
# Condors     115.446512
# Squires     114.051314
# Floridians  112.654545
# Stars       112.354497
# Colonels    111.625296

# %%
df.groupby(by='game_location')['pts'].mean()

# CARA BACANYA
# group berdasarkan 'game_location' -> Hanya ada 3, Away Home dan Neutral
# lalu di lihat berdasarkan mean points
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %% [markdown]
# ### untuk pengelompokan biasanya (categorical)[Numerik]

# %%
# Contoh Elaborasi lain

grup = df.groupby(by='game_location')
grup

# %%
grup.get_group('A')
# ini untuk  mengambil data di game location yg away
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 1                1            0     NYK     Knicks   68  1300.0000  1306.7233
# ...

# %%
 grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %% [markdown]
# ###GROUPING pakek groupby hanya bisa terima 1 input.
# ### Sehingga jika perlu lebih dari 1 kelompok maka pakai [] dibuat menjadi list

# %%
#CONTOH

# %%
df.groupby(by=['year_id','game_location','game_result'])[['pts']].mean()
#JANGAN LUPA pada Syntax Agregasi di [][] 2x biar tampilannya bagus
# Out:
#                                           pts
# year_id game_location game_result
# 1947    A             L             63.273148
#                       W             72.149254
#         H             L             62.559701
#                       W             73.254630
# 1948    A             L             67.233871
# ...                                       ...
# 2015    A             W            105.400000
#         H             L             95.117117
#                       W            105.759947
#         N             L             90.000000
#                       W            104.000000
#
# [298 rows x 1 columns]

# %%
#di mixed dengan QUERY

df[(df['year_id']>2010) &
   (df['fran_id']=='Celtics')] .groupby(by=['year_id','game_location','game_result'])[['pts']].mean()
# Out:
#                                           pts
# year_id game_location game_result
# 2011    A             L             85.095238
#                       W            101.120000
#         H             L             90.111111
#                       W            101.083333
# 2012    A             L             87.360000
#                       W             95.611111
#         H             L             82.272727
#                       W             95.062500
# 2013    A             L             90.137931
#                       W            100.333333
#         H             L             89.266667
#                       W            101.928571
# 2014    A             L             93.375000
#                       W            105.111111
#         H             L             92.640000
#                       W            102.625000
# 2015    A             L             99.125000
#                       W            103.473684
#         H             L             97.636364
# ...

# %% [markdown]
# #Manipulating Column

# %%
nba = df.copy()

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %% [markdown]
# ### RUBAH NAMA
# ##### .rename ()

# %%
# .rename (columns/row{'key':'values'})
#key = nama lama
#values = nama baru

# %%
nba.rename(columns={'game_location':'loc','game_result' : 'result'},inplace=True)
# Pada data frame sudah terganti loc dan result
# namun ini hanya berupa tampilan pada function ini saja.
# Sehingga perlu 1 step lagi agar perubahan ini dapat tersimpan yaitu dengan overwrite nba = nba.rename(columns={'game_location':'loc','game_result' : 'result'})
# Atau nba.rename(columns={'game_location':'loc','game_result' : 'result'},inplace=True)

# %%
nba.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# ### Buang column

# %%
# .drop
# CONTOH :

# %%
nba.drop(labels=['elo_i','elo_n'],axis=1,inplace=True)

# axis = 1 -> Menghapus KOLOM
# Pada data frame juga sudah di hapus namun beoum tersimpan secara paten, perlu di overwrite atau in.place=True

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %% [markdown]
# #Creating Column

# %%
nba['selisih_poin']=nba['pts'] - nba['opp_pts']
nba.head()

#Pada data frame sudah terdapat selisih poin
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n loc result  forecast notes  selisih_poin
# ...

# %%
# Buat kolom baru "HASIL"
# Memakai function
# Contoh :

def hasil(selisih):
  if selisih > 0 :
    return 'Menang'
  elif selisih < 0 :
    return 'Kalah'
  else :
    return 'draw'

# %%
hasil_pertandingan=[]

for i in nba.head()

# %% [markdown]
# # NAMBAH KOLOM PAKEK IF MASIH BINGUNG

# %% [markdown]
# #Specifying Data types

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  datetime64[ns]
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  opp_elo_i     126314 non-null  float64
#  16  opp_elo_n     126314 non-null  float64
# ...

# %%
# merubah data type di date_games

nba['date_game'] = pd.to_datetime(nba['date_game'])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  datetime64[ns]
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  opp_elo_i     126314 non-null  float64
#  16  opp_elo_n     126314 non-null  float64
# ...

# %% [markdown]
# #Handling missing values
#
# #### Masih belum faham

# %%
#using .dropna() :

# %%
rows_without_missing_data = nba.dropna()

# %%
rows_without_missing_data.shape
# Out:
# (5424, 22)

# %%
data_without_missing_columns = nba.dropna(axis=1)

# %%
data_without_missing_columns.shape
# Out:
# (126314, 21)

# %%
#CONTOH REPLACE Missing Value

# %%
data_with_default_notes = nba.copy()

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)

# %%
data_with_default_notes["notes"].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %% [markdown]
# #Visualizing Data Frame

# %%
visual = df.groupby(by='fran_id')[['pts']].mean().sort_values(by='pts',ascending=False).head()
visual
# Out:
#                    pts
# fran_id
# Condors     115.446512
# Squires     114.051314
# Floridians  112.654545
# Stars       112.354497
# Colonels    111.625296

# %%
visual.plot()
